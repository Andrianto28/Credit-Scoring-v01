# %%
import pandas as pd
import re
from collections import OrderedDict

# %%
df = pd.read_csv('Data_Coment_IG.csv')
df
# Out:
#           id_user             id_media           posting_taken_at  \
# 0     51245593696  3028678588043349963  2023-02-01 15:50:44+00:00
# 1     51245593696  3028678588043349963  2023-02-01 15:50:44+00:00
# 2     51245593696  3028678588043349963  2023-02-01 15:50:44+00:00
# 3     51245593696  3028678588043349963  2023-02-01 15:50:44+00:00
# 4     51245593696  3028678588043349963  2023-02-01 15:50:44+00:00
# ...           ...                  ...                        ...
# 1906     24239929  3043403566594497220  2023-02-21 23:26:38+00:00
# 1907     24239929  3042765319698898611  2023-02-21 02:18:33+00:00
# 1908     24239929  3042765319698898611  2023-02-21 02:18:33+00:00
# 1909     24239929  3042765319698898611  2023-02-21 02:18:33+00:00
# 1910     24239929  3042765319698898611  2023-02-21 02:18:33+00:00
#
#              id_comment          comment__taken_at     username_upost  \
# 0     18255432901180717  2023-02-19 04:18:31+00:00  denisechariesta91
# 1     17953933943290237  2023-02-19 04:15:36+00:00  denisechariesta91
# 2     17889078227786274  2023-02-17 00:36:35+00:00  denisechariesta91
# 3     17925889880555973  2023-02-16 06:47:19+00:00  denisechariesta91
# 4     17997544162637879  2023-02-15 17:08:01+00:00  denisechariesta91
# ...                 ...                        ...                ...
# 1906  17961479753159077  2023-02-22 01:22:01+00:00    princessyahrini
# 1907  17991954796793623  2023-02-22 00:04:19+00:00    princessyahrini
# 1908  18011484379547444  2023-02-22 00:04:04+00:00    princessyahrini
# 1909  18038139751429190  2023-02-21 08:23:46+00:00    princessyahrini
# 1910  17964063911256799  2023-02-21 03:39:46+00:00    princessyahrini
#
#         fullname_upost                                    biography_upost  \
# 0     Denise Chariesta  pembela kebenaran keadilan wa:081991991992 @fl...
# 1     Denise Chariesta  pembela kebenaran keadilan wa:081991991992 @fl...
# 2     Denise Chariesta  pembela kebenaran keadilan wa:081991991992 @fl...
# 3     Denise Chariesta  pembela kebenaran keadilan wa:081991991992 @fl...
# 4     Denise Chariesta  pembela kebenaran keadilan wa:081991991992 @fl...
# ...                ...                                                ...
# 1906          SYAHRINI                                                NaN
# 1907          SYAHRINI                                                NaN
# 1908          SYAHRINI                                                NaN
# 1909          SYAHRINI                                                NaN
# 1910          SYAHRINI                                                NaN
#
#       is_private_upost                                 profile_pic_url_hd  \
# 0                False  https://instagram.fcgk24-2.fna.fbcdn.net/v/t51...
# 1                False  https://instagram.fcgk24-2.fna.fbcdn.net/v/t51...
# 2                False  https://instagram.fcgk24-2.fna.fbcdn.net/v/t51...
# 3                False  https://instagram.fcgk24-2.fna.fbcdn.net/v/t51...
# 4                False  https://instagram.fcgk24-2.fna.fbcdn.net/v/t51...
# ...                ...                                                ...
# 1906             False  https://instagram.fcgk24-2.fna.fbcdn.net/v/t51...
# 1907             False  https://instagram.fcgk24-2.fna.fbcdn.net/v/t51...
# 1908             False  https://instagram.fcgk24-2.fna.fbcdn.net/v/t51...
# 1909             False  https://instagram.fcgk24-2.fna.fbcdn.net/v/t51...
# 1910             False  https://instagram.fcgk24-2.fna.fbcdn.net/v/t51...
#
#       ufollower_count  ufollowing_count  media_type_postingan  like_postingan  \
# 0              639449                14                     8            1586
# 1              639449                14                     8            1586
# 2              639449                14                     8            1586
# 3              639449                14                     8            1586
# 4              639449                14                     8            1586
# ...               ...               ...                   ...             ...
# 1906         41829672               756                     8               3
# 1907         41829672               756                     8               3
# 1908         41829672               756                     8               3
# 1909         41829672               756                     8               3
# 1910         41829672               756                     8               3
#
#                                                 caption     username_comment  \
# 0     Ud pada pesen PO bunga valentine dari @fleurde...             tya.va88
# 1     Ud pada pesen PO bunga valentine dari @fleurde...             tya.va88
# 2     Ud pada pesen PO bunga valentine dari @fleurde...    aprilliza_diandra
# 3     Ud pada pesen PO bunga valentine dari @fleurde...        sm12980212019
# 4     Ud pada pesen PO bunga valentine dari @fleurde...            fidha_amr
# ...                                                 ...                  ...
# 1906  •\n\n~ Ohayo Gozaimasu Tokyo ~\n\n____________...  hengkikawilarang_id
# 1907  •\n\n~ Tokyo Lyfe ~\n\n______________________ ...      princessyahrini
# 1908  •\n\n~ Tokyo Lyfe ~\n\n______________________ ...      princessyahrini
# 1909  •\n\n~ Tokyo Lyfe ~\n\n______________________ ...                hke57
# 1910  •\n\n~ Tokyo Lyfe ~\n\n______________________ ...                syh55
#
#                                            comment_text
# 0     @ndix_doank jngan ngatain begitu,setiap manusi...
# 1     @____desy mbak, semua orang pernah salah,tapi ...
# 2     Gue lebih suka dia kaya difoto senyum keliatan...
# 3     @____desy stop ngatain gitu mbk gak ada manusi...
# 4               Nis loe lihat postnya Rz dilaporin noh😂
# ...                                                 ...
# 1906                                    Miss u ❤️❤️❤️❤️
# 1907                   @hke57 Bunbunku Tersayangg 💜💜💜💜💜
# 1908              @syh55 MashaAllah 🤲 Alhamdulillah 💜💜💜
# 1909                                  Sayangku sehat2ya
# 1910                    MashaAllaahh tabarakallah❤️❤️❤️
#
# [1911 rows x 17 columns]

# %%
data = df[['id_user', 'id_user', 'id_media', 'username_upost', 'comment_text']]
data
# Out:
#           id_user      id_user             id_media     username_upost  \
# 0     51245593696  51245593696  3028678588043349963  denisechariesta91
# 1     51245593696  51245593696  3028678588043349963  denisechariesta91
# 2     51245593696  51245593696  3028678588043349963  denisechariesta91
# 3     51245593696  51245593696  3028678588043349963  denisechariesta91
# 4     51245593696  51245593696  3028678588043349963  denisechariesta91
# ...           ...          ...                  ...                ...
# 1906     24239929     24239929  3043403566594497220    princessyahrini
# 1907     24239929     24239929  3042765319698898611    princessyahrini
# 1908     24239929     24239929  3042765319698898611    princessyahrini
# 1909     24239929     24239929  3042765319698898611    princessyahrini
# 1910     24239929     24239929  3042765319698898611    princessyahrini
#
#                                            comment_text
# 0     @ndix_doank jngan ngatain begitu,setiap manusi...
# 1     @____desy mbak, semua orang pernah salah,tapi ...
# 2     Gue lebih suka dia kaya difoto senyum keliatan...
# 3     @____desy stop ngatain gitu mbk gak ada manusi...
# 4               Nis loe lihat postnya Rz dilaporin noh😂
# ...                                                 ...
# 1906                                    Miss u ❤️❤️❤️❤️
# 1907                   @hke57 Bunbunku Tersayangg 💜💜💜💜💜
# 1908              @syh55 MashaAllah 🤲 Alhamdulillah 💜💜💜
# 1909                                  Sayangku sehat2ya
# 1910                    MashaAllaahh tabarakallah❤️❤️❤️
#
# [1911 rows x 5 columns]

# %%
def clear(caption):
    #remove angka
    caption = re.sub('[0-9]+', '', str(caption))

    # remove hyperlinks
    caption = re.sub(r'https?:\/\/\S+', '', str(caption))
    
    # remove hashtags
    caption = re.sub(r'#[A-Za-z0-9_]+', '', str(caption))

    # remove symbol
    caption = re.sub(r'[^\x00-\x7f]', '', str(caption))

    #remove coma
    caption = re.sub(r',',' ', str(caption))
    
    #remove double huruf
    captions = ''.join(OrderedDict.fromkeys(caption))
    
    #remove punctuation
    caption = re.sub(r'[^\w\s]', '', str(caption))
    
    return caption

# %%
data['bersih'] = data['comment_text'].apply(lambda x: clear(x))
# Out:
# C:\Users\RanggaSaputra\AppData\Local\Temp\ipykernel_23832\1100895350.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['bersih'] = data['comment_text'].apply(lambda x: clear(x))

# %%
data.isnull().sum()
# Out:
# id_user           0
# id_user           0
# id_media          0
# username_upost    0
# comment_text      0
# bersih            0
# dtype: int64

# %%
# oleh Tala, F.z (2003)
stopwords_buatan=['ada', 'adalah', 'adanya', 'adapun', 'agak', 'agaknya', 'agar', 'akan', 'akankah', 'akhir', 'akhiri', 'akhirnya',
     'aku', 'akulah', 'amat', 'amatlah', 'anda', 'andalah', 'antar', 'antara', 'antaranya', 'apa', 'apaan', 'apabila',
     'apakah', 'apalagi', 'apatah', 'artinya', 'asal', 'asalkan', 'atas', 'atau', 'ataukah', 'ataupun', 'awal', 'awalnya',
     'bagai', 'bagaikan', 'bagaimana', 'bagaimanakah', 'bagaimanapun', 'bagi', 'bagian', 'bahkan', 'bahwa', 'bahwasanya',
     'baik', 'bakal', 'bakalan', 'balik', 'banyak', 'bapak', 'baru', 'bawah', 'beberapa', 'begini', 'beginian', 'beginikah',
     'beginilah', 'begitu', 'begitukah', 'begitulah', 'begitupun', 'bekerja', 'belakang', 'belakangan', 'belum', 'belumlah',
     'benar', 'benarkah', 'benarlah', 'berada', 'berakhir', 'berakhirlah', 'berakhirnya', 'berapa', 'berapakah',
     'berapalah', 'berapapun', 'berarti', 'berawal', 'berbagai', 'berdatangan', 'beri', 'berikan', 'berikut', 'berikutnya',
     'berjumlah', 'berkali-kali', 'berkata', 'berkehendak', 'berkeinginan', 'berkenaan', 'berlainan', 'berlalu',
     'berlangsung', 'berlebihan', 'bermacam', 'bermacam-macam', 'bermaksud', 'bermula', 'bersama', 'bersama-sama',
     'bersiap', 'bersiap-siap', 'bertanya', 'bertanya-tanya', 'berturut', 'berturut-turut', 'bertutur', 'berujar', 'berupa',
     'besar', 'betul', 'betulkah', 'biasa', 'biasanya', 'bila', 'bilakah', 'bisa', 'bisakah', 'boleh', 'bolehkah',
     'bolehlah', 'buat', 'bukan', 'bukankah', 'bukanlah', 'bukannya', 'bulan', 'bung', 'cara', 'caranya', 'cukup',
     'cukupkah', 'cukuplah', 'cuma', 'dahulu', 'dalam', 'dan', 'dapat', 'dari', 'daripada', 'datang', 'dekat', 'demi',
     'demikian', 'demikianlah', 'dengan', 'dng', 'dg', 'depan', 'di', 'dia', 'diakhiri', 'diakhirinya', 'dialah', 'diantara',
     'diantaranya', 'diberi', 'diberikan', 'diberikannya', 'dibuat', 'dibuatnya', 'didapat', 'didatangkan', 'digunakan',
     'diibaratkan', 'diibaratkannya', 'diingat', 'diingatkan', 'diinginkan', 'dijawab', 'dijelaskan', 'dijelaskannya',
     'dikarenakan', 'dikatakan', 'dikatakannya', 'dikerjakan', 'diketahui', 'diketahuinya', 'dikira', 'dilakukan',
     'dilalui', 'dilihat', 'dimaksud', 'dimaksudkan', 'dimaksudkannya', 'dimaksudnya', 'diminta', 'dimintai', 'dimisalkan',
     'dimulai', 'dimulailah', 'dimulainya', 'dimungkinkan', 'dini', 'dipastikan', 'diperbuat', 'diperbuatnya',
     'dipergunakan', 'diperkirakan', 'diperlihatkan', 'diperlukan', 'diperlukannya', 'dipersoalkan', 'dipertanyakan',
     'dipunyai', 'diri', 'dirinya', 'disampaikan', 'disebut', 'disebutkan', 'disebutkannya', 'disini', 'disinilah',
     'ditambahkan', 'ditandaskan', 'ditanya', 'ditanyai', 'ditanyakan', 'ditegaskan', 'ditujukan', 'ditunjuk', 'ditunjuki',
     'ditunjukkan', 'ditunjukkannya', 'ditunjuknya', 'dituturkan', 'dituturkannya', 'diucapkan', 'diucapkannya',
     'diungkapkan', 'dong', 'dua', 'dulu', 'empat', 'enggak', 'enggaknya', 'entah', 'entahlah', 'guna', 'gunakan', 'hal',
     'hampir', 'hanya', 'hanyalah', 'hari', 'harus', 'haruslah', 'harusnya', 'hendak', 'hendaklah', 'hendaknya', 'hingga',
     'ia', 'ialah', 'ibarat', 'ibaratkan', 'ibaratnya', 'ibu', 'ikut', 'ingat', 'ingat-ingat', 'ingin', 'inginkah',
     'inginkan', 'ini', 'inikah', 'inilah', 'itu', 'itukah', 'itulah', 'jadi', 'jadilah', 'jadinya', 'jangan', 'jngn', 'jng', 'jgn', 'jangankan',
     'janganlah', 'jauh', 'jawab', 'jawaban', 'jawabnya', 'jelas', 'jelaskan', 'jelaslah', 'jelasnya', 'jika', 'jikalau',
     'juga', 'jumlah', 'jumlahnya', 'justru', 'kala', 'kalau', 'kalaulah', 'kalaupun', 'kalian', 'kami', 'kamilah', 'kamu',
     'kamulah', 'kan', 'kapan', 'kapankah', 'kapanpun', 'karena', 'krn', 'karenanya', 'kasus', 'kata', 'katakan', 'katakanlah',
     'katanya', 'ke', 'keadaan', 'kebetulan', 'kecil', 'kedua', 'keduanya', 'keinginan', 'kelamaan', 'kelihatan',
     'kelihatannya', 'kelima', 'keluar', 'kembali', 'kemudian', 'kemungkinan', 'kemungkinannya', 'kenapa', 'kepada',
     'kepadanya', 'kesampaian', 'keseluruhan', 'keseluruhannya', 'keterlaluan', 'ketika', 'khususnya', 'kini', 'kinilah',
     'kira', 'kira-kira', 'kiranya', 'kita', 'kitalah', 'kok', 'kurang', 'lagi', 'lagian', 'lah', 'lain', 'lainnya', 'lalu',
     'lama', 'lamanya', 'lanjut', 'lanjutnya', 'lebih', 'lewat', 'lima', 'luar', 'macam', 'maka', 'makanya', 'makin',
     'malah', 'malahan', 'mampu', 'mampukah', 'mana', 'manakala', 'manalagi', 'masa', 'masalah', 'masalahnya', 'masih',
     'masihkah', 'masing', 'masing-masing', 'mau', 'maupun', 'melainkan', 'melakukan', 'melalui', 'melihat', 'melihatnya',
     'memang', 'memastikan', 'memberi', 'memberikan', 'membuat', 'memerlukan', 'memihak', 'meminta', 'memintakan',
     'memisalkan', 'memperbuat', 'mempergunakan', 'memperkirakan', 'memperlihatkan', 'mempersiapkan', 'mempersoalkan',
     'mempertanyakan', 'mempunyai', 'memulai', 'memungkinkan', 'menaiki', 'menambahkan', 'menandaskan', 'menanti',
     'menanti-nanti', 'menantikan', 'menanya', 'menanyai', 'menanyakan', 'mendapat', 'mendapatkan', 'mendatang',
     'mendatangi', 'mendatangkan', 'menegaskan', 'mengakhiri', 'mengapa', 'mengatakan', 'mengatakannya', 'mengenai',
     'mengerjakan', 'mengetahui', 'menggunakan', 'menghendaki', 'mengibaratkan', 'mengibaratkannya', 'mengingat',
     'mengingatkan', 'menginginkan', 'mengira', 'mengucapkan', 'mengucapkannya', 'mengungkapkan', 'menjadi', 'menjawab',
     'menjelaskan', 'menuju', 'menunjuk', 'menunjuki', 'menunjukkan', 'menunjuknya', 'menurut', 'menuturkan',
     'menyampaikan', 'menyangkut', 'menyatakan', 'menyebutkan', 'menyeluruh', 'menyiapkan', 'merasa', 'mereka', 'merekalah',
     'merupakan', 'meski', 'meskipun', 'meyakini', 'meyakinkan', 'minta', 'mirip', 'misal', 'misalkan', 'misalnya', 'mula',
     'mulai', 'mulailah', 'mulanya', 'mungkin', 'mungkinkah', 'nah', 'naik', 'namun', 'nanti', 'nantinya', 'nyaris',
     'nyatanya', 'oleh', 'olehnya', 'pada', 'padahal', 'padanya', 'pak', 'paling', 'panjang', 'pantas', 'para', 'pasti',
     'pastilah', 'penting', 'pentingnya', 'per', 'percuma', 'perlu', 'perlukah', 'perlunya', 'pernah', 'persoalan',
     'pertama', 'pertama-tama', 'pertanyaan', 'pertanyakan', 'pihak', 'pihaknya', 'pukul', 'pula', 'pun', 'punya', 'rasa',
     'rasanya', 'rata', 'rupanya', 'saat', 'saatnya', 'saja', 'sajalah', 'saling', 'sama', 'sama-sama', 'sambil', 'sampai',
     'sampai-sampai', 'sampaikan', 'sana', 'sangat', 'sangatlah', 'satu', 'saya', 'sayalah', 'se', 'sebab', 'sebabnya',
     'sebagai', 'sbg', 'sebagaimana', 'sebagainya', 'sebagian', 'sebaik', 'sebaik-baiknya', 'sebaiknya', 'sebaliknya', 'sebanyak',
     'sebegini', 'sebegitu', 'sebelum', 'sebelumnya', 'sebenarnya', 'seberapa', 'sebesar', 'sebetulnya', 'sebisanya',
     'sebuah', 'sebut', 'sebutlah', 'sebutnya', 'secara', 'secukupnya', 'sedang', 'sedangkan', 'sedemikian', 'sedikit',
     'sedikitnya', 'seenaknya', 'segala', 'segalanya', 'segera', 'seharusnya', 'sehingga', 'seingat', 'sejak', 'sejauh',
     'sejenak', 'sejumlah', 'sekadar', 'sekadarnya', 'sekali', 'sekali-kali', 'sekalian', 'sekaligus', 'sekalipun',
     'sekarang', 'sekarang', 'sekecil', 'seketika', 'sekiranya', 'sekitar', 'sekitarnya', 'sekurang-kurangnya',
     'sekurangnya', 'sela', 'selain', 'selaku', 'selalu', 'selama', 'selama-lamanya', 'selamanya', 'selanjutnya', 'seluruh',
     'seluruhnya', 'semacam', 'semakin', 'semampu', 'semampunya', 'semasa', 'semasih', 'semata', 'semata-mata', 'semaunya',
     'sementara', 'semisal', 'semisalnya', 'sempat', 'semua', 'semuanya', 'semula', 'sendiri', 'sendirian', 'sendirinya',
     'seolah', 'seolah-olah', 'seorang', 'sepanjang', 'sepantasnya', 'sepantasnyalah', 'seperlunya', 'seperti',
     'sepertinya', 'sepihak', 'sering', 'seringnya', 'serta', 'serupa', 'sesaat', 'sesama', 'sesampai', 'sesegera',
     'sesekali', 'seseorang', 'sesuatu', 'sesuatunya', 'sesudah', 'sesudahnya', 'setelah', 'setempat', 'setengah',
     'seterusnya', 'setiap', 'setiba', 'setibanya', 'setidak-tidaknya', 'setidaknya', 'setinggi', 'seusai', 'sewaktu',
     'siap', 'siapa', 'siapakah', 'siapapun', 'sini', 'sinilah', 'soal', 'soalnya', 'suatu', 'sudah', 'sudahkah',
     'sudahlah', 'supaya', 'tadi', 'tadinya', 'tahu', 'tahun', 'tak', 'tambah', 'tambahnya', 'tampak', 'tampaknya',
     'tandas', 'tandasnya', 'tanpa', 'tanya', 'tanyakan', 'tanyanya', 'tapi', 'tegas', 'tegasnya', 'telah', 'tempat',
     'tengah', 'tentang', 'tentu', 'tentulah', 'tentunya', 'tepat', 'terakhir', 'terasa', 'terbanyak', 'terdahulu',
     'terdapat', 'terdiri', 'terhadap', 'terhadapnya', 'teringat', 'teringat-ingat', 'terjadi', 'terjadilah', 'terjadinya',
     'terkira', 'terlalu', 'terlebih', 'terlihat', 'termasuk', 'ternyata', 'tersampaikan', 'tersebut', 'tersebutlah',
     'tertentu', 'tertuju', 'terus', 'terutama', 'tetap', 'tetapi', 'tiap', 'tiba', 'tiba-tiba', 'tidak', 'tidakkah',
     'tidaklah', 'tiga', 'tinggi', 'toh', 'tunjuk', 'turut', 'tutur', 'tuturnya', 'ucap', 'ucapnya', 'ujar', 'ujarnya',
     'umum', 'umumnya', 'ungkap', 'ungkapnya', 'untuk', 'usah', 'usai', 'waduh', 'wah', 'wahai', 'waktu', 'waktunya',
     'walau', 'walaupun', 'wong', 'yaitu', 'yakin', 'yakni', 'yang','yg']

# %%
#Remove Mention
data['bersih'] = data['bersih'].str.replace('@\S+', ' ', case=False)

#Remove extra whitespace
data['bersih'] = data['bersih'].str.replace("\s(2)", ' ', case=False)

#selain huruf
data['bersih'] = data['bersih'].str.replace('[^a-zA-Z \n\.]'," ")

#newline
data['bersih'] = data['bersih'].str.replace('\n'," ")
# Out:
# C:\Users\RanggaSaputra\AppData\Local\Temp\ipykernel_23832\2080759355.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['bersih'] = data['bersih'].str.replace('@\S+', ' ', case=False)
# C:\Users\RanggaSaputra\AppData\Local\Temp\ipykernel_23832\2080759355.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['bersih'] = data['bersih'].str.replace('@\S+', ' ', case=False)
# C:\Users\RanggaSaputra\AppData\Local\Temp\ipykernel_23832\2080759355.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['bersih'] = data['bersih'].str.replace("\s(2)", ' ', case=False)
# C:\Users\RanggaSaputra\AppData\Local\Temp\ipykernel_23832\2080759355.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['bersih'] = data['bersih'].str.replace("\s(2)", ' ', case=False)
# C:\Users\RanggaSaputra\AppData\Local\Temp\ipykernel_23832\2080759355.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['bersih'] = data['bersih'].str.replace('[^a-zA-Z \n\.]'," ")
# C:\Users\RanggaSaputra\AppData\Local\Temp\ipykernel_23832\2080759355.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['bersih'] = data['bersih'].str.replace('[^a-zA-Z \n\.]'," ")
# C:\Users\RanggaSaputra\AppData\Local\Temp\ipykernel_23832\2080759355.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['bersih'] = data['bersih'].str.replace('\n'," ")

# %%
data
# Out:
#           id_user      id_user             id_media     username_upost  \
# 0     51245593696  51245593696  3028678588043349963  denisechariesta91
# 1     51245593696  51245593696  3028678588043349963  denisechariesta91
# 2     51245593696  51245593696  3028678588043349963  denisechariesta91
# 3     51245593696  51245593696  3028678588043349963  denisechariesta91
# 4     51245593696  51245593696  3028678588043349963  denisechariesta91
# ...           ...          ...                  ...                ...
# 1906     24239929     24239929  3043403566594497220    princessyahrini
# 1907     24239929     24239929  3042765319698898611    princessyahrini
# 1908     24239929     24239929  3042765319698898611    princessyahrini
# 1909     24239929     24239929  3042765319698898611    princessyahrini
# 1910     24239929     24239929  3042765319698898611    princessyahrini
#
#                                            comment_text  \
# 0     @ndix_doank jngan ngatain begitu,setiap manusi...
# 1     @____desy mbak, semua orang pernah salah,tapi ...
# 2     Gue lebih suka dia kaya difoto senyum keliatan...
# 3     @____desy stop ngatain gitu mbk gak ada manusi...
# 4               Nis loe lihat postnya Rz dilaporin noh😂
# ...                                                 ...
# 1906                                    Miss u ❤️❤️❤️❤️
# 1907                   @hke57 Bunbunku Tersayangg 💜💜💜💜💜
# 1908              @syh55 MashaAllah 🤲 Alhamdulillah 💜💜💜
# 1909                                  Sayangku sehat2ya
# 1910                    MashaAllaahh tabarakallah❤️❤️❤️
#
#                                                  bersih
# 0     ndix doank jngan ngatain begitu setiap manusia...
# 1         desy mbak  semua orang pernah salah tapi m...
# 2     Gue lebih suka dia kaya difoto senyum keliatan...
# 3         desy stop ngatain gitu mbk gak ada manusia...
# 4                Nis loe lihat postnya Rz dilaporin noh
# ...                                                 ...
# 1906                                            Miss u
# 1907                           hke Bunbunku Tersayangg
# 1908                     syh MashaAllah  Alhamdulillah
# 1909                                   Sayangku sehatya
# 1910                          MashaAllaahh tabarakallah
#
# [1911 rows x 6 columns]

# %%
#=========================================================================#
#import stopword
from nltk.corpus import stopwords 
stopwords_indonesia = stopwords.words('indonesian')

data['bersih'] = data['bersih'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords_buatan)]))
#=========================================================================#
data
# Out:
# C:\Users\RanggaSaputra\AppData\Local\Temp\ipykernel_23832\1615040340.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['bersih'] = data['bersih'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords_buatan)]))
#           id_user      id_user             id_media     username_upost  \
# 0     51245593696  51245593696  3028678588043349963  denisechariesta91
# 1     51245593696  51245593696  3028678588043349963  denisechariesta91
# 2     51245593696  51245593696  3028678588043349963  denisechariesta91
# 3     51245593696  51245593696  3028678588043349963  denisechariesta91
# 4     51245593696  51245593696  3028678588043349963  denisechariesta91
# ...           ...          ...                  ...                ...
# 1906     24239929     24239929  3043403566594497220    princessyahrini
# 1907     24239929     24239929  3042765319698898611    princessyahrini
# 1908     24239929     24239929  3042765319698898611    princessyahrini
# 1909     24239929     24239929  3042765319698898611    princessyahrini
# 1910     24239929     24239929  3042765319698898611    princessyahrini
#
#                                            comment_text  \
# 0     @ndix_doank jngan ngatain begitu,setiap manusi...
# 1     @____desy mbak, semua orang pernah salah,tapi ...
# 2     Gue lebih suka dia kaya difoto senyum keliatan...
# 3     @____desy stop ngatain gitu mbk gak ada manusi...
# 4               Nis loe lihat postnya Rz dilaporin noh😂
# ...                                                 ...
# 1906                                    Miss u ❤️❤️❤️❤️
# 1907                   @hke57 Bunbunku Tersayangg 💜💜💜💜💜
# 1908              @syh55 MashaAllah 🤲 Alhamdulillah 💜💜💜
# 1909                                  Sayangku sehat2ya
# 1910                    MashaAllaahh tabarakallah❤️❤️❤️
#
#                                                  bersih
# 0                 ndix doank jngan ngatain manusia dosa
# 1     desy mbak orang salah msh pnya kesempatan beru...
# 2     Gue suka kaya difoto senyum keliatan banget ka...
# 3     desy stop ngatain gitu mbk gak manusia sempurn...
# 4                Nis loe lihat postnya Rz dilaporin noh
# ...                                                 ...
# 1906                                             Miss u
# 1907                            hke Bunbunku Tersayangg
# 1908                       syh MashaAllah Alhamdulillah
# 1909                                   Sayangku sehatya
# 1910                          MashaAllaahh tabarakallah
#
# [1911 rows x 6 columns]

# %%
data.isnull().sum()
# Out:
# id_user           0
# id_user           0
# id_media          0
# username_upost    0
# comment_text      0
# bersih            0
# dtype: int64

# %% [markdown]
# Bert

# %%
from transformers import pipeline
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch

# %%
pretrained= "mdhugol/indonesia-bert-sentiment-classification"
model = AutoModelForSequenceClassification.from_pretrained(pretrained)
tokenizer = AutoTokenizer.from_pretrained(pretrained)

# %%
sentiment_analysis = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)

# %%
label_index = {'LABEL_0': 'Positif', 'LABEL_1': 'Netral', 'LABEL_2': 'Negatif'}

# %%
def get_sentiment_indobert(text):
    result = sentiment_analysis(text)
    status = label_index[result[0]['label']]
    return status

# %%
data['sentiment_indobert'] = data['bersih'].apply(get_sentiment_indobert)
# Out:
# C:\Users\RanggaSaputra\AppData\Local\Temp\ipykernel_23832\3729188245.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['sentiment_indobert'] = data['bersih'].apply(get_sentiment_indobert)

# %%
data.to_csv('Data_Comment_IG_Label.csv', index=False)

# %% [markdown]
# RoBERTa

# %%
from transformers import pipeline

pretrained_name = "w11wo/indonesian-roberta-base-sentiment-classifier"

roberta = pipeline(
    "sentiment-analysis",
    model=pretrained_name,
    tokenizer=pretrained_name
)
# Out:
# Downloading (…)lve/main/config.json: 100%|█████████████████████████████████████████████| 929/929 [00:00<00:00, 282kB/s]
# Downloading (…)"pytorch_model.bin";: 100%|██████████████████████████████████████████| 499M/499M [00:44<00:00, 11.3MB/s]
# Downloading (…)okenizer_config.json: 100%|█████████████████████████████████████████████| 328/328 [00:00<00:00, 111kB/s]
# Downloading (…)olve/main/vocab.json: 100%|███████████████████████████████████████████| 808k/808k [00:01<00:00, 653kB/s]
# Downloading (…)olve/main/merges.txt: 100%|███████████████████████████████████████████| 467k/467k [00:02<00:00, 173kB/s]
# Downloading (…)/main/tokenizer.json: 100%|█████████████████████████████████████████| 1.38M/1.38M [00:04<00:00, 323kB/s]
# Downloading (…)cial_tokens_map.json: 100%|█████████████████████████████████████████████| 239/239 [00:00<00:00, 120kB/s]

# %%
def get_sentiment_roberta(text):
    result = roberta(text)
    status = result[0]['label']
    return status

# %%
data['sentiment_roberta'] = data['bersih'].apply(get_sentiment_roberta)

# %%
data.to_csv('Data_Comment_IG_Label.csv', index=False)

# %%
data = pd.read_csv('Data_Comment_IG_Label.csv')
data
# Out:
#           id_user    id_user.1             id_media     username_upost  \
# 0     51245593696  51245593696  3028678588043349963  denisechariesta91
# 1     51245593696  51245593696  3028678588043349963  denisechariesta91
# 2     51245593696  51245593696  3028678588043349963  denisechariesta91
# 3     51245593696  51245593696  3028678588043349963  denisechariesta91
# 4     51245593696  51245593696  3028678588043349963  denisechariesta91
# ...           ...          ...                  ...                ...
# 1712     24239929     24239929  3043403566594497220    princessyahrini
# 1713     24239929     24239929  3042765319698898611    princessyahrini
# 1714     24239929     24239929  3042765319698898611    princessyahrini
# 1715     24239929     24239929  3042765319698898611    princessyahrini
# 1716     24239929     24239929  3042765319698898611    princessyahrini
#
#                                            comment_text  \
# 0     @ndix_doank jngan ngatain begitu,setiap manusi...
# 1     @____desy mbak, semua orang pernah salah,tapi ...
# 2     Gue lebih suka dia kaya difoto senyum keliatan...
# 3     @____desy stop ngatain gitu mbk gak ada manusi...
# 4               Nis loe lihat postnya Rz dilaporin noh😂
# ...                                                 ...
# 1712                                    Miss u ❤️❤️❤️❤️
# 1713                   @hke57 Bunbunku Tersayangg 💜💜💜💜💜
# 1714              @syh55 MashaAllah 🤲 Alhamdulillah 💜💜💜
# 1715                                  Sayangku sehat2ya
# 1716                    MashaAllaahh tabarakallah❤️❤️❤️
#
#                                                  bersih sentiment_indobert  \
# 0                 ndix doank jngan ngatain manusia dosa            Negatif
# 1     desy mbak orang salah msh pnya kesempatan beru...             Netral
# 2     Gue suka kaya difoto senyum keliatan banget ka...            Positif
# 3     desy stop ngatain gitu mbk gak manusia sempurn...            Negatif
# 4                Nis loe lihat postnya Rz dilaporin noh             Netral
# ...                                                 ...                ...
# 1712                                             Miss u            Positif
# 1713                            hke Bunbunku Tersayangg            Positif
# 1714                       syh MashaAllah Alhamdulillah            Positif
# 1715                                   Sayangku sehatya            Positif
# 1716                          MashaAllaahh tabarakallah            Positif
#
#      sentiment_roberta
# 0             negative
# 1             negative
# 2             positive
# 3             negative
# 4             negative
# ...                ...
# 1712          positive
# 1713          positive
# 1714          positive
# 1715          positive
# 1716          positive
#
# [1717 rows x 8 columns]

# %%
data.dropna(axis=0, subset=['bersih'], inplace=True)
data
# Out:
#           id_user    id_user.1             id_media     username_upost  \
# 0     51245593696  51245593696  3028678588043349963  denisechariesta91
# 1     51245593696  51245593696  3028678588043349963  denisechariesta91
# 2     51245593696  51245593696  3028678588043349963  denisechariesta91
# 3     51245593696  51245593696  3028678588043349963  denisechariesta91
# 4     51245593696  51245593696  3028678588043349963  denisechariesta91
# ...           ...          ...                  ...                ...
# 1712     24239929     24239929  3043403566594497220    princessyahrini
# 1713     24239929     24239929  3042765319698898611    princessyahrini
# 1714     24239929     24239929  3042765319698898611    princessyahrini
# 1715     24239929     24239929  3042765319698898611    princessyahrini
# 1716     24239929     24239929  3042765319698898611    princessyahrini
#
#                                            comment_text  \
# 0     @ndix_doank jngan ngatain begitu,setiap manusi...
# 1     @____desy mbak, semua orang pernah salah,tapi ...
# 2     Gue lebih suka dia kaya difoto senyum keliatan...
# 3     @____desy stop ngatain gitu mbk gak ada manusi...
# 4               Nis loe lihat postnya Rz dilaporin noh😂
# ...                                                 ...
# 1712                                    Miss u ❤️❤️❤️❤️
# 1713                   @hke57 Bunbunku Tersayangg 💜💜💜💜💜
# 1714              @syh55 MashaAllah 🤲 Alhamdulillah 💜💜💜
# 1715                                  Sayangku sehat2ya
# 1716                    MashaAllaahh tabarakallah❤️❤️❤️
#
#                                                  bersih sentiment_indobert  \
# 0                 ndix doank jngan ngatain manusia dosa            Negatif
# 1     desy mbak orang salah msh pnya kesempatan beru...             Netral
# 2     Gue suka kaya difoto senyum keliatan banget ka...            Positif
# 3     desy stop ngatain gitu mbk gak manusia sempurn...            Negatif
# 4                Nis loe lihat postnya Rz dilaporin noh             Netral
# ...                                                 ...                ...
# 1712                                             Miss u            Positif
# 1713                            hke Bunbunku Tersayangg            Positif
# 1714                       syh MashaAllah Alhamdulillah            Positif
# 1715                                   Sayangku sehatya            Positif
# 1716                          MashaAllaahh tabarakallah            Positif
#
#      sentiment_roberta
# 0             negative
# 1             negative
# 2             positive
# 3             negative
# 4             negative
# ...                ...
# 1712          positive
# 1713          positive
# 1714          positive
# 1715          positive
# 1716          positive
#
# [1717 rows x 8 columns]

# %%
data.to_csv('Data_Comment_IG_Label.csv', index=False)
